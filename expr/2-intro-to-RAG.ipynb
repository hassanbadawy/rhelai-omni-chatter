# %% [markdown]
# # 🦙 Llama Stack & RAG: Building Intelligent Agents
#
# This notebook demonstrates **Retrieval-Augmented Generation (RAG)** - a powerful technique that enables AI models to access and reason about external documents and knowledge bases.
#
# **Why RAG Matters:**
# Instead of relying only on training data, RAG-enhanced models can reference your specific documents, course materials, and knowledge bases to provide accurate, cited responses.

# %%
import uuid

from llama_stack_client import RAGDocument, LlamaStackClient
from termcolor import cprint

import sys
# sys.path.append('..')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import uuid
# ----> 3 from llama_stack_client import RAGDocument, LlamaStackClient
#       4 from termcolor import cprint
#       6 import sys
#
# ImportError: cannot import name 'RAGDocument' from 'llama_stack_client' (/opt/miniconda3/lib/python3.13/site-packages/llama_stack_client/__init__.py)

# %% [markdown]
# ## 🔗 Connect to Llama Stack
#
# Connect to Llama Stack - the AI engine that orchestrates all RAG operations. Llama Stack acts as the central hub that coordinates:
# - Vector database operations (storage and retrieval)
# - Document processing and chunking
# - LLM inference with retrieved context
# - Agent workflows and tool usage

# %%
# The base URL points to your Llama Stack server deployment
base_url = "http://llama-stack-service:8321"
base_url = "https://llama-stack-user1-canopy.apps.ocp.9xgvv.sandbox3434.opentlc.com"

# Create the Llama Stack client
client = LlamaStackClient(
    base_url=base_url,
    provider_data=None
)

print(f"Connected to Llama Stack server")

# Configs for model and sampling
model_id = "llama32"
temperature = 0.0
max_tokens = 512
stream = False

# Configure the sampling strategy based on temperature
if temperature > 0.0:
    top_p = 0.95  # Nucleus sampling parameter
    strategy = {"type": "top_p", "temperature": temperature, "top_p": top_p}
else:
    strategy = {"type": "greedy"}  # Always pick most likely token

# Package sampling parameters for the inference API
sampling_params = {
    "strategy": strategy,
    "max_tokens": max_tokens,
}

print(f"Model: {model_id}")
print(f"Sampling Parameters: {sampling_params}")
print(f"Stream: {stream}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       3 base_url = "https://llama-stack-user1-canopy.apps.ocp.9xgvv.sandbox3434.opentlc.com"
#       5 # Create the Llama Stack client
# ----> 6 client = LlamaStackClient(
#       7     base_url=base_url,
#       8     provider_data=None
#       9 )
#      11 print(f"Connected to Llama Stack server")
#      13 # Configs for model and sampling
#
# NameError: name 'LlamaStackClient' is not defined

# %% [markdown]
# ## Register the Vector Database

# %%
# This tells Llama Stack how to connect to and use your vector database
vs = client.vector_stores.create(
    name="my_citations_db",
    extra_body={
        "embedding_model": "all-MiniLM-L6-v2",
        "embedding_dimension": 384,
        "provider_id": "milvus",
        "vector_db_id": "test"
    }
)

print(f"📊 Created vector database with ID: {vs.id}")
# Out:
# INFO:httpx:HTTP Request: POST http://llama-stack-service:8321/v1/vector_stores "HTTP/1.1 426 Upgrade Required"
# ---------------------------------------------------------------------------
# APIStatusError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 # This tells Llama Stack how to connect to and use your vector database
# ----> 2 vs = client.vector_stores.create(
#       3     name="my_citations_db",
#       4     extra_body={
#       5         "embedding_model": "all-MiniLM-L6-v2",
#       6         "embedding_dimension": 384,
#       7         "provider_id": "milvus",
#       8         "vector_db_id": "test"
#       9     }
#      10 )
#      12 print(f"📊 Created vector database with ID: {vs.id}")
#
# File /opt/app-root/lib64/python3.12/site-packages/llama_stack_client/resources/vector_stores/vector_stores.py:123, in VectorStoresResource.create(self, chunking_strategy, expires_after, file_ids, metadata, name, extra_headers, extra_query, extra_body, timeout)
#      84 def create(
#      85     self,
#      86     *,
#    (...)     97     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#      98 ) -> VectorStore:
#      99     """Creates a vector store.
#     100
#     101     Generate an OpenAI-compatible vector store with the
#    (...)    121       timeout: Override the client-level default timeout for this request, in seconds
#     122     """
# --> 123     return self._post(
#     124         "/v1/vector_stores",
#     125         body=maybe_transform(
#     126             {
#     127                 "chunking_strategy": chunking_strategy,
#     128                 "expires_after": expires_after,
#     129                 "file_ids": file_ids,
#     130                 "metadata": metadata,
#     131                 "name": name,
#     132             },
#     133             vector_store_create_params.VectorStoreCreateParams,
#     134         ),
#     135         options=make_request_options(
#     136             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     137         ),
#     138         cast_to=VectorStore,
#     139     )
#
# File /opt/app-root/lib64/python3.12/site-packages/llama_stack_client/_base_client.py:1252, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1238 def post(
#    1239     self,
#    1240     path: str,
#    (...)   1247     stream_cls: type[_StreamT] | None = None,
#    1248 ) -> ResponseT | _StreamT:
#    1249     opts = FinalRequestOptions.construct(
#    1250         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1251     )
# -> 1252     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/app-root/lib64/python3.12/site-packages/llama_stack_client/_base_client.py:1054, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1051             err.response.read()
#    1053         log.debug("Re-raising status error")
# -> 1054         raise self._make_status_error_from_response(err.response) from None
#    1056     break
#    1058 assert response is not None, "could not resolve response (should never happen)"
#
# APIStatusError: Error code: 426 - {'error': {'message': 'Client version 0.3.0 is not compatible with server version 0.4.2.1+rhai0. Please update your client.'}}

# %% [markdown]
# ## 📚 Document Ingestion and Processing
#
# This is where the **RAG Layer** comes into action! We'll use Llama Stack's RAG Tool to automatically:
#
# 1. **Download** documents from URLs
# 2. **Process** PDF content and extract text
# 3. **Chunk** large documents into optimal pieces (512 tokens each)
# 4. **Embed** each chunk using the embedding model
# 5. **Store** vectors and metadata in the vector database
#
# **Two ways to ingest documents:**
# - **Direct Vector IO**: Insert pre-processed chunks directly into your Vector Database
# - **Llama Stack RAG Tool** (what we're using): Automatic processing from URLs or files
#
# We use the RAG Tool because it allows us to easily ingest documents from URLs, files, etc. and automatically chunks them into smaller pieces.

# %%
# List of URLs (in this case just 1) to process
urls = [
    "https://raw.githubusercontent.com/rhoai-genaiops/deploy-lab/main/university-data/canopy-in-botany.pdf",
]

# Display what we're about to ingest
print("📖 Ingesting documents into RAG system...")
for i, url in enumerate(urls):
    print(f"  • Document {i+1}: {url}")

# Download and upload files using the new API
import requests
from io import BytesIO

try:
    uploaded_file_ids = []
    
    for i, url in enumerate(urls):
        print(f"\n📥 Downloading document from: {url}")
        response = requests.get(url)
        response.raise_for_status()
        
        # Create a file-like object from the downloaded content
        file_content = BytesIO(response.content)
        file_content.name = f"canopy-in-botany-{i}.pdf"
        
        # Upload file using the new files API
        uploaded_file = client.files.create(
            file=file_content,
            purpose="assistants"  # Required purpose parameter
        )
        
        uploaded_file_ids.append(uploaded_file.id)
        print(f"✅ Uploaded file with ID: {uploaded_file.id}")
    
    # Add files to the vector store with chunking configuration
    for file_id in uploaded_file_ids:
        client.vector_stores.files.create(
            vector_store_id=vs.id,
            file_id=file_id,
            chunking_strategy={
                "type": "static",
                "static": {
                    "max_chunk_size_tokens": 512,
                    "chunk_overlap_tokens": 50
                }
            }
        )
        print(f"✅ Added file {file_id} to vector store with chunking")
    
    print("\n✅ Document ingestion complete!")
    print("🎯 Your documents are now searchable via semantic similarity!")
    
except Exception as e:
    print(f"\n❌ Document ingestion failed: {e}")
    print("💡 This might be due to PDF processing issues or network connectivity. Try with different documents or check the PDF accessibility.")
# Out:
# 📖 Ingesting documents into RAG system...
#   • Document 1: https://raw.githubusercontent.com/rhoai-genaiops/deploy-lab/main/university-data/canopy-in-botany.pdf
#
# 📥 Downloading document from: https://raw.githubusercontent.com/rhoai-genaiops/deploy-lab/main/university-data/canopy-in-botany.pdf
# INFO:httpx:HTTP Request: POST http://llama-stack-service:8321/v1/files "HTTP/1.1 200 OK"
# ✅ Uploaded file with ID: file-b738fcfa82784314ac3db70d0b695eb5
# INFO:httpx:HTTP Request: POST http://llama-stack-service:8321/v1/vector_stores/test/files "HTTP/1.1 200 OK"
# ✅ Added file file-b738fcfa82784314ac3db70d0b695eb5 to vector store with chunking
#
# ✅ Document ingestion complete!
# 🎯 Your documents are now searchable via semantic similarity!

# %% [markdown]
# # Choice time! 🙋‍♂️
#
# Now that we have ingested a document, you can choose to either try out RAG here in the notebook or use the Llama Playground.
#
# 🧾 If you prefer notebook, continue to the next cell.
#
# 🦙 If you wish to use Llama Stack Playground, open it up (the URL is something like this: `https://llama-stack-playground-<USER_NAME>-canopy.<CLUSTER_DOMAIN>`) and in the left menu select the `Document Collections` we just ingested (there should only be 1, and named something like `test`).
#
# Then try these questions (with and without the document selected):
#
# - What are the types of Canopy?
# - What is the structure of Canopy?

# %% [markdown]
# ![genaiops-rag-meme.png](genaiops-rag-meme.png)

# %%
queries = [
    "What are the types of Canopy?",
    "What is the structure of Canopy?",
]

# %% [markdown]
# ## First, without RAG
# First, let's test the response without RAG in the picture so we have something to compare with.
# Notice that this is very similar to the code we used before to send a prompt to the model, system prompt included and everything

# %%
for prompt in queries:
    cprint(f"\nUser> {prompt}", "blue")

    messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ]

    response = client.chat.completions.create(
        model=model_id,
        messages=messages,
        temperature=temperature,
        max_tokens=max_tokens,
        stream=True,
    )

    cprint("inference> ", color="magenta", end='')
    
    # Handle streaming response - tokens arrive one by one
    for chunk in response:
        if hasattr(chunk, 'choices') and chunk.choices:
            delta = chunk.choices[0].delta
            if hasattr(delta, 'content') and delta.content:
                cprint(delta.content, color="magenta", end='')
        elif hasattr(chunk, 'content'):
            cprint(chunk.content, color="magenta", end='')
# Out:
# INFO:httpx:HTTP Request: POST http://llama-stack-service:8321/v1/chat/completions "HTTP/1.1 200 OK"
# User> What are the types of Canopy?
# inference> A canopy can refer to different types of structures or coverings, depending on the context. Here are some common types of canopies:
#
# 1. **Agricultural Canopy**: A layer of vegetation or a network of trees that provides shade, improves soil health, and supports biodiversity in agricultural landscapes.
# 2. **Greenhouse Canopy**: A transparent or translucent structure that allows sunlight to enter and warm the interior, while also providing shade and protection from the elements.
# 3. **Tree Canopy**: The layer of leaves and branches of trees that forms the uppermost layer of a forest ecosystem, providing habitat and shelter for various plant and animal species.
# 4. **Aerial Canopy**: A network of cables, wires, or ropes that support a structure, such as a bridge or a walkway, while also providing shade and protection from the elements.
# 5. **Outdoor Canopy**: A fabric or metal structure that provides shade and shelter from the elements, often used in outdoor events, weddings, or picnics.
# 6. **Car Canopy**: A roof or cover that fits over a car, providing protection from the elements and improving aerodynamics.
# 7. **Gazebo Canopy**: A freestanding structure with a roof or canopy that provides shade and shelter in a garden or outdoor space.
# 8. **Tunnel Canopy**: A covered passageway or walkway that provides shade and protection from the elements, often used in construction or industrial settings.
# 9. **Canopy System**: A network of interconnected structures, such as trees or poles, that support a canopy or a network of vegetation.
# 10. **Geodesic Canopy**: A dome-shaped structure made of interconnected triangles, often used as a temporary or permanent shelter, or as a decorative feature.
#
# These are just a few examples of the different types of canopies that exist. The specific type of canopy will depend on the
# INFO:httpx:HTTP Request: POST http://llama-stack-service:8321/v1/chat/completions "HTTP/1.1 200 OK"
#  context, purpose, and design requirements.
# User> What is the structure of Canopy?
# inference> I'm assuming you're referring to the popular video game Canopy. Unfortunately, I don't have specific information about the game Canopy, as there may be multiple games with that title.
#
# However, I can try to provide some general information. Canopy is a survival horror game developed by Supermassive Games, the same studio behind the Until Dawn series. The game was released in 2023 for PC and consoles.
#
# If you're referring to a different game, please provide more context or details, and I'll do my best to provide the information you're looking for.
#
# Alternatively, if you're referring to the game's structure, I can try to provide some general information about survival horror games. Typically, these games follow a non-linear structure, where the player must navigate through a series of environments, making choices that affect the story and gameplay.
#
# In Canopy, the game's structure may involve:
#
# 1. Exploration: Players must explore a series of environments, including forests, caves, and abandoned buildings.
# 2. Resource management: Players must manage resources such as food, water, and health to survive.
# 3. Crafting: Players can craft items and tools to aid in their survival.
# 4. Stealth and combat: Players must use stealth and combat mechanics to evade or defeat enemies.
# 5. Branching storylines: The game's story may branch out based on the player's choices, leading to multiple possible endings.
#
# If you have any specific questions about Canopy or its structure, feel free to ask, and I'll do my best to help.

# %% [markdown]
# ## 🔍 Testing RAG Retrieval and Generation
#
# Now let's test the complete **RAG Pipeline** - this demonstrates how all three layers work together:
#
# ### The RAG Process:
# 1. **🔍 Query Processing**: Convert user question into embeddings
# 2. **📚 Semantic Retrieval**: Find most similar document chunks in vector database
# 3. **🔗 Context Assembly**: Combine user question with retrieved chunks
# 4. **🤖 Generation**: LLM generates informed response using both its training and the retrieved context
# 5. **📖 Citation**: Response includes references to source documents
#
# **Why this works better than normal LLMs:**
# - **Grounded responses**: Answers are based on your specific documents
# - **Up-to-date**: Add new documents without retraining the model
# - **Traceable**: Every answer can be traced back to source material
# - **Accurate**: Reduces hallucination by providing factual context

# %%
for prompt in queries:
    cprint(f"\nUser> {prompt}", "blue")
    
    # Query the vector database to find relevant document chunks
    search_results = client.vector_stores.search(
        vector_store_id=vs.id,
        query=prompt,
        max_num_results=5,
        search_mode="vector"  # Use vector similarity search
    )

    retrieved_chunks = []
    for i, result in enumerate(search_results.data):
        chunk_content = result.content if hasattr(result, 'content') else str(result)
        metadata = result.metadata if hasattr(result, 'metadata') else {}
        retrieved_chunks.append(f"Result {i+1}\nContent: {chunk_content}\nMetadata: {metadata}")
    
    rag_response_content = "\n\n".join(retrieved_chunks)
    
    cprint(f"Text chunks from vector search found: {len(search_results.data)} chunks")
    cprint(f"\n--- Search Results ---", "yellow")
    cprint(rag_response_content[:500] + "..." if len(rag_response_content) > 500 else rag_response_content, "cyan")

    
    messages = [
        {"role": "system", "content": "You are a helpful assistant."}
    ]

    # Now we inject the retrieved content as context into our prompt, this is the key part to make RAG work as this is where the LLM gets the document information
    extended_prompt = f"Please answer the given query using the context below.\n\nCONTEXT:\n{rag_response_content}\n\nQUERY:\n{prompt}"
    messages.append({"role": "user", "content": extended_prompt})

    response = client.chat.completions.create(
        model=model_id,
        messages=messages,
        temperature=temperature,
        max_tokens=max_tokens,
        stream=True,
    )

    cprint("inference> ", color="magenta", end='')
    
    # Handle streaming response - tokens arrive one by one
    for chunk in response:
        if hasattr(chunk, 'choices') and chunk.choices:
            delta = chunk.choices[0].delta
            if hasattr(delta, 'content') and delta.content:
                cprint(delta.content, color="magenta", end='')
        elif hasattr(chunk, 'content'):
            cprint(chunk.content, color="magenta", end='')
# Out:
# INFO:httpx:HTTP Request: POST http://llama-stack-service:8321/v1/vector_stores/test/search "HTTP/1.1 200 OK"
# User> What are the types of Canopy?
# Text chunks from vector search found: 3 chunks
#
# --- Search Results ---
# Result 1
# Content: [DataContent(text="Canopy in Botany\n1. Definition of Canopy\nIn botany, the term 'canopy' refers to the uppermost layer of a forest formed by the crowns of tall\ntrees. This layer creates a continuous or semi-continuous cover of foliage and branches that\nstretches above the forest floor. The concept of the canopy is especially relevant in tropical and\ntemperate forests, where it forms a distinct horizontal layer in the vertical structure of the forest. The\ncanopy plays a si...
# INFO:httpx:HTTP Request: POST http://llama-stack-service:8321/v1/chat/completions "HTTP/1.1 200 OK"
# inference> According to the provided context, there are four main types of canopies:
#
# 1. Closed Canopy: Found in dense forests like tropical rainforests, this type features overlapping tree crowns that form a continuous cover.
# 2. Open Canopy: Common in savannas and dry forests, tree crowns do not touch, allowing more light to penetrate.
# 3. Multi-layered Canopy: Characteristic of mature tropical forests, this includes multiple strata of foliage-from emergent trees to lower canopy layers-each supporting distinct species.
# 4. Monotypic Canopy: Dominated by one tree species, such as eucalyptus forests or commercial plantations. Biodiversity is usually lower, but this structure is common in managed ecosystems.
#
# Additionally, there is a fifth type mentioned:
#
# 5. Seasonal Canopy: In deciduous forests, the canopy is seasonal, losing its leaves in autumn and regrowing them in spring. This affects light dynamics and ecological processes
# INFO:httpx:HTTP Request: POST http://llama-stack-service:8321/v1/vector_stores/test/search "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://llama-stack-service:8321/v1/chat/completions "HTTP/1.1 200 OK"
#  seasonally.
# User> What is the structure of Canopy?
# Text chunks from vector search found: 3 chunks
#
# --- Search Results ---
# Result 1
# Content: [DataContent(text="Canopy in Botany\n1. Definition of Canopy\nIn botany, the term 'canopy' refers to the uppermost layer of a forest formed by the crowns of tall\ntrees. This layer creates a continuous or semi-continuous cover of foliage and branches that\nstretches above the forest floor. The concept of the canopy is especially relevant in tropical and\ntemperate forests, where it forms a distinct horizontal layer in the vertical structure of the forest. The\ncanopy plays a si...
# inference> According to the provided context, the structure of the canopy is a key characteristic of a forest's vertical stratification. It generally consists of the outermost branches and leaves of the tallest trees. The height of the canopy varies depending on forest type, ranging from about 10 meters in boreal forests to over 40 meters in tropical rainforests. Beneath the main canopy, additional layers may exist, including the emergent layer (trees that grow above the general canopy level), the understory, and the forest floor.

# %% [markdown]
# ## 🎉 You've Built a Complete RAG System!
#
# Buuut... it's running in an in-line vector database, with no automation or redundancy, and is not connected to our application yet.
# Let's go through the steps to move this from a proof of concept to a production ready system!
